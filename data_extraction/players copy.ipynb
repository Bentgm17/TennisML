# %%
# %run "create_dataframe.py"

import pandas as pd
import matplotlib.pyplot as plt
import os
import warnings
from ipynb.fs.full.create_dataframe import computeDataframe
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("stats_df.csv",index_col=0).reset_index(drop=True)
display(df)
# Out:
#        match_id  l_sf_elo  l_i_o_elo_rank  w_sf_elo  w_i_o_elo_rank  \
# 0         80994    1801.0          1764.0    1862.0          1804.0
# 1         80996    1947.0          1917.0    1807.0          1912.0
# 2         80998    1891.0          1910.0    1893.0          1901.0
# 3         80999    1842.0          1826.0    1902.0          1937.0
# 4         81000    1713.0          1771.0    1918.0          1877.0
# ...         ...       ...             ...       ...             ...
# 34384    177391    2363.0          2217.0    2273.0          2139.0
# 34385    177392    2159.0          2125.0    2363.0          2217.0
# 34386    177393    2204.0          2143.0    2363.0          2217.0
# 34387    177394    2159.0          2125.0    2273.0          2139.0
# 34388    177396    2204.0          2143.0    2159.0          2125.0
#
#        winner_id  loser_id  w_rank  l_rank  w_elo_r  ...  w_r_game_w  \
# 0           1613       587    94.0   220.0   1789.0  ...    0.600000
# 1           1117      1332    65.0    72.0   1901.0  ...    0.500000
# 2           1377      1439    69.0    66.0   1906.0  ...    0.142857
# 3           1409       772    89.0   100.0   1904.0  ...    0.600000
# 4            954      1407    45.0   117.0   1900.0  ...    0.200000
# ...          ...       ...     ...     ...      ...  ...         ...
# 34384       6219      4742     3.0     2.0   2231.0  ...    0.066667
# 34385       4742     26577     2.0     6.0   2404.0  ...    0.214286
# 34386       4742     25897     2.0     8.0   2399.0  ...    0.222222
# 34387       6219     26577     3.0     6.0   2222.0  ...    0.363636
# 34388      26577     25897     6.0     8.0   2153.0  ...    0.181818
#
#       l_r_game_w    w_gm_w    l_gm_w  w_g_dominance  l_g_dominance  \
# 0       0.333333  0.631579  0.368421       1.800000       0.555556
# 1       0.111111  0.705882  0.294118       4.500000       0.222222
# 2       0.200000  0.482759  0.517241       0.714286       1.400000
# 3       0.300000  0.650000  0.350000       2.000000       0.500000
# 4       0.000000  0.600000  0.400000       0.000000       0.000000
# ...          ...       ...       ...            ...            ...
# 34384   0.142857  0.448276  0.551724       0.466667       2.142857
# 34385   0.133333  0.551724  0.448276       1.607143       0.622222
# 34386   0.000000  0.631579  0.368421       0.000000       0.000000
# 34387   0.166667  0.608696  0.391304       2.181818       0.458333
# 34388   0.090909  0.545455  0.454545       2.000000       0.500000
#
#        w_br_ratio  l_br_ratio   w_win_p   l_win_p
# 0        1.600000    0.625000  0.167940  0.832060
# 1        0.727273    1.375000  0.543066  0.456934
# 2        0.933333    1.071429  0.538778  0.461222
# 3        1.500000    0.666667  0.410316  0.589684
# 4        0.000000    0.000000  0.599397  0.400603
# ...           ...         ...       ...       ...
# 34384    0.083333   12.000000  0.791749  0.208251
# 34385    0.642857    1.555556  0.596629  0.403371
# 34386    0.000000    0.000000  0.624002  0.375998
# 34387    1.142857    0.875000  0.464084  0.535916
# 34388    1.000000    1.000000  0.927967  0.072033
#
# [34389 rows x 68 columns]

# %%
data_extractor=computeDataframe(df)
data_extractor.walkover()
# Out:
# 122it [00:00, 10930.83it/s]
# [2008.0, 2019.0, 2016.0, 2022.0]
# -0.006923837784371889
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
